# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\DELL\\MY PROJECTS\\car cost prediction.csv")
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0              2  convertible          rwd           front        88.6  ...
# ...

# %%
data=df.replace("?",100)
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               100  alfa-romero       gas        std
# 1            3               100  alfa-romero       gas        std
# 2            1               100  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0              2  convertible          rwd           front        88.6  ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
m=LabelEncoder()

# %%
data["symboling"]=m.fit_transform(data["symboling"])
#data["normalized-losses"]=m.fit_transform(data["normalized-losses"])
#data["losses"]=m.fit_transform(data["losses"])
data["make"]=m.fit_transform(data["make"])
data["fuel-type"]=m.fit_transform(data["fuel-type"])
data["aspiration"]=m.fit_transform(data["aspiration"])
#data["num-of-doors"]=m.fit_transform(data["num-of-doors"])
data["body-style"]=m.fit_transform(data["body-style"])
data["drive-wheels"]=m.fit_transform(data["drive-wheels"])
data["engine-location"]=m.fit_transform(data["engine-location"])
data["wheel-base"]=m.fit_transform(data["wheel-base"])
data["length"]=m.fit_transform(data["length"])
data["width"]=m.fit_transform(data["width"])
#data["height"]=m.fit_transform(data["height"])
#data["curb-weight"]=m.fit_transform(data["curb-weight"])
data["engine-type"]=m.fit_transform(data["engine-type"])
data["num-of-cylinders"]=m.fit_transform(data["num-of-cylinders"])
data["engine-size"]=m.fit_transform(data["engine-size"])
data["fuel-system"]=m.fit_transform(data["fuel-system"])
#data["bore"]=m.fit_transform(data["bore"])
#data["stroke"]=m.fit_transform(data["stroke"])
#data["compression-ratio	horsepower"]=m.fit_transform(data["compression-ratio-horsepower"])
#data["peak-rpm"]=m.fit_transform(data["peak-rpm"])
#data["city-mpg"]=m.fit_transform(data["city-mpg"])
data["highway-mpg"]=m.fit_transform(data["highway-mpg"])
data
# Out:
#      symboling normalized-losses  make  fuel-type  aspiration num-of-doors  \
# 0            5               100     0          1           0            2
# 1            5               100     0          1           0            2
# 2            3               100     0          1           0            2
# 3            4               164     1          1           0            4
# 4            4               164     1          1           0            4
# ..         ...               ...   ...        ...         ...          ...
# 200          1                95    21          1           0            4
# 201          1                95    21          1           1            4
# 202          1                95    21          1           0            4
# 203          1                95    21          0           1            4
# 204          1                95    21          1           1            4
#
# ...

# %%
data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'h8', 'curb-w8', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
y=df["price"]
y

x=[]
for i in data['num-of-doors']:
    x.append(int(i))




norm=[]
for i in data['normalized-losses']:
    norm.append(int(i))


m=[]
for i in data['bore']:
    m.append(float(i))
    
    



st=[]
for i in data['stroke']:
    st.append(float(i))
    



pr=[]
for i in data['peak-rpm']:
    pr.append(float(i))
    
    



c=[]
for i in data['price']:
    c.append(float(i))
    
    



hr=[]
for i in data['horsepower']:
    hr.append(float(i))
perfect=data.drop(['num-of-doors','bore','stroke','horsepower','peak-rpm','price','num-of-doors'],axis=1)
perfect['num-of-doors']=[i for i in x]

perfect['bore']=m

perfect['stroke']=st

perfect['horsepower']=hr

perfect['peak-rpm']=pr
perfect['normalized-losses']=norm
perfect['price']=c
df=perfect.replace({"price":100},8000)
df
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  body-style  \
# 0            5                100     0          1           0           0
# 1            5                100     0          1           0           0
# 2            3                100     0          1           0           2
# 3            4                164     1          1           0           3
# 4            4                164     1          1           0           3
# ..         ...                ...   ...        ...         ...         ...
# 200          1                 95    21          1           0           3
# 201          1                 95    21          1           1           3
# 202          1                 95    21          1           0           3
# 203          1                 95    21          0           1           3
# 204          1                 95    21          1           1           3
#
# ...

# %%
import numpy as np
df["CAR_PRICE"]=np.log10(df["price"])

# %%
car=df.drop(["price"],axis=1)
car
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  body-style  \
# 0            5                100     0          1           0           0
# 1            5                100     0          1           0           0
# 2            3                100     0          1           0           2
# 3            4                164     1          1           0           3
# 4            4                164     1          1           0           3
# ..         ...                ...   ...        ...         ...         ...
# 200          1                 95    21          1           0           3
# 201          1                 95    21          1           1           3
# 202          1                 95    21          1           0           3
# 203          1                 95    21          0           1           3
# 204          1                 95    21          1           1           3
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
m=StandardScaler()
car["symboling"]=m.fit_transform(car[["symboling"]])
car['normalized-losses']=m.fit_transform(car[["normalized-losses"]])

car["make"]=m.fit_transform(car[["make"]])
car["fuel-type"]=m.fit_transform(car[["fuel-type"]])
car["aspiration"]=m.fit_transform(car[["aspiration"]])
data["num-of-doors"]=m.fit_transform(car[["num-of-doors"]])
car["body-style"]=m.fit_transform(car[["body-style"]])
car["drive-wheels"]=m.fit_transform(car[["drive-wheels"]])
car["engine-location"]=m.fit_transform(car[["engine-location"]])
car["wheel-base"]=m.fit_transform(car[["wheel-base"]])
car["length"]=m.fit_transform(car[["length"]])
car["width"]=m.fit_transform(car[["width"]])
car['h8']=m.fit_transform(car[['h8']])
car['curb-w8']=m.fit_transform(car[['curb-w8']])
car["engine-type"]=m.fit_transform(car[["engine-type"]])
car["num-of-cylinders"]=m.fit_transform(car[["num-of-cylinders"]])
car["engine-size"]=m.fit_transform(car[["engine-size"]])
car["fuel-system"]=m.fit_transform(car[["fuel-system"]])
data["bore"]=m.fit_transform(car[["bore"]])
car["stroke"]=m.fit_transform(car[["stroke"]])
#car["compression-ratio	horsepower"]=m.fit_transform(car[["compression-ratio-horsepower"])
car["peak-rpm"]=m.fit_transform(car[["city-mpg"]])
car['highway-mpg']=m.fit_transform(car[['highway-mpg']])
car
# Out:
#      symboling  normalized-losses      make  fuel-type  aspiration  \
# 0     1.743470          -0.536488 -1.948256   0.328798   -0.469295
# 1     1.743470          -0.536488 -1.948256   0.328798   -0.469295
# 2     0.133509          -0.536488 -1.948256   0.328798   -0.469295
# 3     0.938490           1.414378 -1.788499   0.328798   -0.469295
# 4     0.938490           1.414378 -1.788499   0.328798   -0.469295
# ..         ...                ...       ...        ...         ...
# 200  -1.476452          -0.688899  1.406641   0.328798   -0.469295
# 201  -1.476452          -0.688899  1.406641   0.328798    2.130854
# 202  -1.476452          -0.688899  1.406641   0.328798   -0.469295
# 203  -1.476452          -0.688899  1.406641  -3.041381    2.130854
# 204  -1.476452          -0.688899  1.406641   0.328798    2.130854
#
#      body-style  drive-wheels  engine-location  wheel-base    length  ...  \
# 0     -3.050975      1.213330        -0.121867   -1.474700 -0.652539  ...
# ...

# %%
x=car.drop(["CAR_PRICE"],axis=1)
y=car["CAR_PRICE"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
print(len(x_train))
print(len(x_test))
# Out:
# 143
# 62

# %%
from sklearn.model_selection import KFold,cross_val_score

# %%
import matplotlib.pyplot as plt
plt.scatter(x="horsepower",y="CAR_PRICE",data=car)

# %%
import seaborn as sns
sns.boxplot(x="horsepower",y="CAR_PRICE",data=car)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
from sklearn.feature_selection import RFE
rfe=RFE(model,2)
rfe_res=rfe.fit(x_train,y_train)
print(rfe_res.n_features_)
print(rfe_res.support_)
print(rfe.ranking_)
i=list(zip(car.columns,rfe_res.support_,rfe.ranking_))

for l in i:
    print(l)
# Out:
# 2
# [False False False False False False False  True False False False False
#   True False False False False False False False False False False False
#  False]
# [ 9 19  4 18 16 14  3  1  2  7  8 15  1  6 11 10  5 21 22 17 23 13 12 20
#  24]
# ('symboling', False, 9)
# ('normalized-losses', False, 19)
# ('make', False, 4)
# ('fuel-type', False, 18)
# ('aspiration', False, 16)
# ('body-style', False, 14)
# ('drive-wheels', False, 3)
# ('engine-location', True, 1)
# ('wheel-base', False, 2)
# ('length', False, 7)
# ('width', False, 8)
# ('h8', False, 15)
# ('curb-w8', True, 1)
# ('engine-type', False, 6)
# ('num-of-cylinders', False, 11)
# ('engine-size', False, 10)
# ('fuel-system', False, 5)
# ('compression-ratio', False, 21)
# ('city-mpg', False, 22)
# ('highway-mpg', False, 17)
# ('num-of-doors', False, 23)
# ('bore', False, 13)
# ('stroke', False, 12)
# ('horsepower', False, 20)
# ('peak-rpm', False, 24)

# %%
x_train.columns[~rfe_res.ranking_]
# Out:
# Index(['engine-size', 'body-style', 'num-of-doors', 'drive-wheels',
#        'wheel-base', 'width', 'bore', 'horsepower', 'stroke',
#        'compression-ratio', 'fuel-system', 'length', 'horsepower', 'city-mpg',
#        'engine-type', 'num-of-cylinders', 'highway-mpg', 'fuel-type', 'model',
#        'engine-location', 'normalized-losses', 'height', 'curb-weight',
#        'aspiration', 'symboling'],
#       dtype='object')

# %%
# Plot showing fuelsystem and fueltype
plt.figure(figsize = (12, 10))
sns.factorplot(x = 'fuel-system', col = 'fuel-type',  data = car ,kind='count')
plt.show()

# %%
import seaborn as sns
sns.pairplot(car[['CAR_PRICE','curb-w8','wheel-base','length','width','horsepower','bore','engine-size','city-mpg','highway-mpg']])
plt.show()

# %%
car.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'h8', 'curb-w8', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'compression-ratio', 'city-mpg',
#        'highway-mpg', 'num-of-doors', 'bore', 'stroke', 'horsepower',
#        'peak-rpm', 'CAR_PRICE'],
#       dtype='object')

# %%
#Complete Heat map
plt.figure(figsize = (20, 10))
sns.heatmap(car.corr(), annot = True)
plt.show()

# %%
#Scatter Plot showing price and curbweight
plt.figure(figsize = (10,8))
sns.scatterplot(x='curb-w8',y='CAR_PRICE',data = car, edgecolor = 'red', color = 'black')

# %%
#Plotting sub plots with box plots to get inferences 
plt.figure(figsize=(20, 30))
plt.subplot(4,2,1)
sns.boxplot(x = 'fuel-type', y = 'CAR_PRICE', data = car, linewidth=3)
plt.subplot(4,2,2)
sns.boxplot(x = 'body-style', y = 'CAR_PRICE', data = car, linewidth=3)
plt.subplot(4,2,3)
sns.boxplot(x = 'drive-wheels', y = 'CAR_PRICE', data = car, linewidth=3)
plt.subplot(4,2,4)
sns.boxplot(x = 'engine-location', y = 'CAR_PRICE', data = car, linewidth=3)
plt.subplot(4,2,5)
sns.boxplot(x = 'engine-type', y = 'CAR_PRICE', data = car, linewidth=3)
plt.subplot(4,2,6)
sns.boxplot(x = 'num-of-cylinders', y = 'CAR_PRICE', data = car, linewidth=3)
plt.subplot(4,2,7)
sns.boxplot(x = 'fuel-system', y = 'CAR_PRICE', data = car, linewidth=3)
plt.subplot(4,2,8)
sns.boxplot(x = 'CAR_PRICE', y = 'make', data = car ,linewidth=3)

plt.show()

# %%
car.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'h8', 'curb-w8', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'compression-ratio', 'city-mpg',
#        'highway-mpg', 'num-of-doors', 'bore', 'stroke', 'horsepower',
#        'peak-rpm', 'CAR_PRICE'],
#       dtype='object')

# %%
c_p=car.rename(columns={"h8":"height","curb-w8":"curb-weight","make":"model"})
c_p
# Out:
#      symboling  normalized-losses     model  fuel-type  aspiration  \
# 0     1.743470          -0.536488 -1.948256   0.328798   -0.469295
# 1     1.743470          -0.536488 -1.948256   0.328798   -0.469295
# 2     0.133509          -0.536488 -1.948256   0.328798   -0.469295
# 3     0.938490           1.414378 -1.788499   0.328798   -0.469295
# 4     0.938490           1.414378 -1.788499   0.328798   -0.469295
# ..         ...                ...       ...        ...         ...
# 200  -1.476452          -0.688899  1.406641   0.328798   -0.469295
# 201  -1.476452          -0.688899  1.406641   0.328798    2.130854
# 202  -1.476452          -0.688899  1.406641   0.328798   -0.469295
# 203  -1.476452          -0.688899  1.406641  -3.041381    2.130854
# 204  -1.476452          -0.688899  1.406641   0.328798    2.130854
#
#      body-style  drive-wheels  engine-location  wheel-base    length  ...  \
# 0     -3.050975      1.213330        -0.121867   -1.474700 -0.652539  ...
# ...

# %%
nt=c_p.drop(["CAR_PRICE"],axis=1)
t=c_p["CAR_PRICE"]

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(nt,t,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.feature_selection import RFE
rfe=RFE(lr,3)
rfe_res=rfe.fit(x_train,y_train)
list(zip(x_train.columns,rfe_res.support_,rfe_res.ranking_))
# Out:
# [('symboling', False, 8),
#  ('normalized-losses', False, 18),
#  ('model', False, 3),
#  ('fuel-type', False, 17),
#  ('aspiration', False, 15),
#  ('body-style', False, 13),
#  ('drive-wheels', False, 2),
#  ('engine-location', True, 1),
#  ('wheel-base', True, 1),
#  ('length', False, 6),
#  ('width', False, 7),
#  ('height', False, 14),
#  ('curb-weight', True, 1),
#  ('engine-type', False, 5),
#  ('num-of-cylinders', False, 10),
#  ('engine-size', False, 9),
#  ('fuel-system', False, 4),
#  ('compression-ratio', False, 20),
#  ('city-mpg', False, 21),
#  ('highway-mpg', False, 16),
#  ('num-of-doors', False, 22),
#  ('bore', False, 12),
#  ('stroke', False, 11),
#  ('horsepower', False, 19),
#  ('peak-rpm', False, 23)]

# %%
model=lr.fit(x_train,y_train)
y_predict=model.predict(x_test)
y_predict
# Out:
# array([4.1022795 , 4.00975089, 3.90826284, 4.11355818, 4.11408435,
#        3.99108949, 3.86036639, 4.22321391, 3.82331473, 3.86297617,
#        4.27933346, 3.90066891, 4.16717481, 4.55945113, 3.96396889,
#        4.00773345, 4.01638678, 4.10792984, 4.02705163, 4.2243005 ,
#        3.84173344, 4.11049415, 4.37852668, 4.36733182, 4.11355818,
#        3.80313465, 4.45632489, 3.83960414, 3.86546389, 4.03510846,
#        3.82266653, 4.27364099, 4.09684471, 3.83340397, 4.09267935,
#        3.7245853 , 3.9890227 , 4.20163461, 3.77785579, 3.82445337,
#        4.07339527, 4.22001722, 3.84261321, 4.26965596, 3.93606406,
#        3.80931917, 4.05179926, 4.1214042 , 3.86238316, 4.26167354,
#        4.50357944, 3.84305743, 3.80916905, 3.93764144, 4.31071391,
#        4.33650928, 3.82955605, 4.26396349, 3.95033439, 3.86028099,
#        4.46861881, 3.90594438])

# %%
y_predict.shape
# Out:
# (62,)

# %%
y_test.shape
# Out:
# (62,)

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test,y_predict,color="k")
plt.show()

# %%
x_test.shape
# Out:
# (62, 25)

# %%
y_test.shape
# Out:
# (62,)

# %%
sns.distplot(y_predict,bins=5)

# %%
from sklearn.metrics import r2_score
round(r2_score(y_test, y_predict),2)
# Out:
# 0.84

# %%
x_test.shape
# Out:
# (62, 25)

# %%
y_test.shape
# Out:
# (62,)

# %%
x_train.shape
# Out:
# (143, 25)

# %%
y_train.shape
# Out:
# (143,)
