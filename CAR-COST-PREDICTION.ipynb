# %%
#import the data
import pandas as pd
df=pd.read_csv("C:\\Users\\DELL\\MY PROJECTS\\car cost prediction.csv")
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0              2  convertible          rwd           front        88.6  ...
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'h8', 'curb-w8', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
#rename the columns of name
data=df.rename(columns={"make":"model","h8":"height","curb-w8":"curb-weight",})
data
# Out:
#      symboling normalized-losses        model fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0              2  convertible          rwd           front        88.6  ...
# ...

# %%
#cheking for null values
x=data.isnull()
x.sum()
# Out:
# symboling            0
# normalized-losses    0
# model                0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
#gathering all the punctuation marks
import string
string.punctuation
#checking is for punctuation marks with each if any in the data
for i in string.punctuation:
    x=data.astype(str)==str(i)
    print(i,x.sum())
# Out:
# ! symboling            0
# normalized-losses    0
# model                0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64
# " symboling            0
# normalized-losses    0
# model                0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# ...

# %%
#from above absorvation i finded that there are some punctuation "?" marks are there.
import numpy as np
#replacing that "?" all punctuations with NaN
x=data.replace({"?":np.NaN})
#filling that values with fillna method if not we can take mean and replace them
y=x.fillna(method="bfill")
y.head()
# Out:
#    symboling normalized-losses        model fuel-type aspiration num-of-doors  \
# 0          3               164  alfa-romero       gas        std            2
# 1          3               164  alfa-romero       gas        std            2
# 2          1               164  alfa-romero       gas        std            2
# 3          2               164         audi       gas        std            4
# 4          2               164         audi       gas        std            4
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
#again checking for punctuation
a=y.astype(str)=="?"
a.sum()
# Out:
# symboling            0
# normalized-losses    0
# model                0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
#again checking for nulls
b=y.isnull()
b.sum()
# Out:
# symboling            0
# normalized-losses    0
# model                0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
#check for columns names for further use 
y.columns
# Out:
# Index(['symboling', 'normalized-losses', 'model', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
#counting and comparing which fuel-cars and fuel-systems are mostly using
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize = (12, 10))
sns.catplot(x = 'fuel-system', col = 'fuel-type',  data = y ,kind='count',aspect=2)
plt.show()

# %% [markdown]
# from above catplot we can absorb that in diesel fuel type mostly idi[INDIRECT INJECTION],
# and in gas fuel type mpfi[MULTI POINT FUEL INJECTION] is used.

# %%
y.head()
# Out:
#    symboling normalized-losses        model fuel-type aspiration num-of-doors  \
# 0          3               164  alfa-romero       gas        std            2
# 1          3               164  alfa-romero       gas        std            2
# 2          1               164  alfa-romero       gas        std            2
# 3          2               164         audi       gas        std            4
# 4          2               164         audi       gas        std            4
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
#checking the data type for each attribute
for i in y.columns:
    print(i,y[i].dtype)
# Out:
# symboling int64
# normalized-losses object
# model object
# fuel-type object
# aspiration object
# num-of-doors object
# body-style object
# drive-wheels object
# engine-location object
# wheel-base float64
# length float64
# width float64
# height float64
# curb-weight int64
# engine-type object
# num-of-cylinders object
# engine-size int64
# fuel-system object
# bore object
# stroke object
# compression-ratio float64
# horsepower object
# peak-rpm object
# city-mpg int64
# highway-mpg int64
# price object

# %%
#representing the strings which are appear in the form of numbers
price=[]
for i in y["price"]:
    price.append(i)
print(price,end="")

peak_rpm=[]
for i in y["peak-rpm"]:
    peak_rpm.append(i)
print(peak_rpm,end="")

norm=[]
for i in y['normalized-losses']:
    norm.append(i)
print(norm,end="")

nod=[]
for i in y['num-of-doors']:
    nod.append(i)
print(nod,end="")


bore=[]
for i in y['bore']:
    bore.append(i)
print(bore,end="")

stroke=[]
for i in y['stroke']:
    stroke.append(i)
print(stroke,end="")

hp=[]
for i in y['horsepower']:
    hp.append(i)
print(hp,end="")
# Out:
# ['13495', '16500', '16500', '13950', '17450', '15250', '17710', '18920', '23875', '16430', '16430', '16925', '20970', '21105', '24565', '30760', '41315', '36880', '5151', '6295', '6575', '5572', '6377', '7957', '6229', '6692', '7609', '8558', '8921', '12964', '6479', '6855', '5399', '6529', '7129', '7295', '7295', '7895', '9095', '8845', '10295', '12945', '10345', '6785', '11048', '11048', '11048', '32250', '35550', '36000', '5195', '6095', '6795', '6695', '7395', '10945', '11845', '13645', '15645', '8845', '8495', '10595', '10245', '10795', '11245', '18280', '18344', '25552', '28248', '28176', '31600', '34184', '35056', '40960', '45400', '16503', '5389', '6189', '6669', '7689', '9959', '8499', '12629', '14869', '14489', '6989', '8189', '9279', '9279', '5499', '7099', '6649', '6849', '7349', '7299', '7799', '7499', '7999', '8249', '8949', '9549', '13499', '14399', '13499', '17199', '19699', '18399', '11900', '13200', '12440', '13860', '15580', '16900', '16695', '17075', '16630', '179
# ...

# %%
#converting that string to integers and floats
price=[]
for i in y["price"]:
    price.append(int(i))
print(price,end="")

peak_rpm=[]
for i in y["peak-rpm"]:
    peak_rpm.append(int(i))
print(peak_rpm,end="")

norm=[]
for i in y['normalized-losses']:
    norm.append(int(i))
print(norm,end="")

nod=[]
for i in y['num-of-doors']:
    nod.append(int(i))
print(nod,end="")



bore=[]
for i in y['bore']:
    bore.append(float(i))
print(bore,end="")

stroke=[]
for i in y['stroke']:
    stroke.append(float(i))
print(stroke,end="")

hp=[]
for i in y['horsepower']:
    hp.append(int(i))
print(hp,end="")
# Out:
# [13495, 16500, 16500, 13950, 17450, 15250, 17710, 18920, 23875, 16430, 16430, 16925, 20970, 21105, 24565, 30760, 41315, 36880, 5151, 6295, 6575, 5572, 6377, 7957, 6229, 6692, 7609, 8558, 8921, 12964, 6479, 6855, 5399, 6529, 7129, 7295, 7295, 7895, 9095, 8845, 10295, 12945, 10345, 6785, 11048, 11048, 11048, 32250, 35550, 36000, 5195, 6095, 6795, 6695, 7395, 10945, 11845, 13645, 15645, 8845, 8495, 10595, 10245, 10795, 11245, 18280, 18344, 25552, 28248, 28176, 31600, 34184, 35056, 40960, 45400, 16503, 5389, 6189, 6669, 7689, 9959, 8499, 12629, 14869, 14489, 6989, 8189, 9279, 9279, 5499, 7099, 6649, 6849, 7349, 7299, 7799, 7499, 7999, 8249, 8949, 9549, 13499, 14399, 13499, 17199, 19699, 18399, 11900, 13200, 12440, 13860, 15580, 16900, 16695, 17075, 16630, 17950, 18150, 5572, 7957, 6229, 6692, 7609, 8921, 12764, 22018, 32528, 34028, 37028, 9295, 9295, 9895, 11850, 12170, 15040, 15510, 18150, 18620, 5118, 7053, 7603, 7126, 7775, 9960, 9233, 11259, 7463, 10198, 8013, 11694, 5348, 6338, 6488
# ...

# %%
#assigning that converted integers to the columns
y['horsepower']=hp

y['stroke']=stroke

y['bore']=bore

y['num-of-doors']=nod

y['normalized-losses']=norm

y["peak-rpm"]=peak_rpm

y["price"]=price
#to avoid the warnings while executing
import warnings
import numpy as np
warnings.filterwarnings("ignore")
#the given car prices are at high values if we plot them then accuracy will not get more 
#for that reason i use log to decrease their values 
#to the lower vales with out changing the values
y["CAR_PRICE"]=np.log(y["price"])

# %%
#There are some strings which visible to us same as string
#we have to convert them into integer then only we can continue further process
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in y.columns:
    y[i]=le.fit_transform(y[i])
    
#again checking for data type for better conformation
for i in y.columns:
    print(i,y[i].dtype)
# Out:
# symboling int64
# normalized-losses int64
# model int64
# fuel-type int64
# aspiration int64
# num-of-doors int64
# body-style int64
# drive-wheels int64
# engine-location int64
# wheel-base int64
# length int64
# width int64
# height int64
# curb-weight int64
# engine-type int64
# num-of-cylinders int64
# engine-size int64
# fuel-system int64
# bore int64
# stroke int64
# compression-ratio int64
# horsepower int64
# peak-rpm int64
# city-mpg int64
# highway-mpg int64
# price int64
# CAR_PRICE int64

# %%
#as we can see above we taken log for the price and assigned it to new column. so no need with
#column old one, drop it then.

car=y.drop(["price"],axis=1)
car
# Out:
#      symboling  normalized-losses  model  fuel-type  aspiration  num-of-doors  \
# 0            5                 42      0          1           0             0
# 1            5                 42      0          1           0             0
# 2            3                 42      0          1           0             0
# 3            4                 42      1          1           0             1
# 4            4                 42      1          1           0             1
# ..         ...                ...    ...        ...         ...           ...
# 200          1                 13     21          1           0             1
# 201          1                 13     21          1           1             1
# 202          1                 13     21          1           0             1
# 203          1                 13     21          0           1             1
# 204          1                 13     21          1           1             1
#
# ...

# %%
#plotting the heatmap to represent the cor-relation with each and each attribute
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
sns.heatmap(car.corr(),annot=True,linewidth=2,center=True)
plt.show()

# %% [markdown]
# BY THE ABOVE HEAT MAP WE CAN ABSORB THAT curb-weight HAS HIGH
# CO-RELATION WITH wheel-base, length, width,engine-size, horsepower, CAR_PRICE

# %%
car.columns
# Out:
# Index(['symboling', 'normalized-losses', 'model', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'CAR_PRICE'],
#       dtype='object')

# %%
#plot the graph which has co-relations with many attributes and price
plt.figure(figsize = (10,8))
sns.scatterplot(x='curb-weight',y='CAR_PRICE',data = car, edgecolor = 'red', color = 'black')

# %%
#plotting and absorbing all the high cor-relationed attributes with pairplot
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(car[['wheel-base','length','width','engine-size','horsepower',"CAR_PRICE"]])
plt.show()

# %%
#from above pair plot we can absorb outliers to remove and represent boxplot is helpfull.
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
plt.subplot(3,2,1)
sns.boxplot(x='wheel-base',y="CAR_PRICE",data=car)

plt.subplot(3,2,2)
sns.boxplot(x='length',y="CAR_PRICE",data=car)

plt.subplot(3,2,3)
sns.boxplot(x='width',y="CAR_PRICE",data=car)

plt.subplot(3,2,4)
sns.boxplot(x='engine-size',y="CAR_PRICE",data=car)

plt.subplot(3,2,5)
sns.boxplot(x='horsepower',y="CAR_PRICE",data=car)
plt.show()

# %%
#Now seperating the data as input and output data
a=car.drop(["CAR_PRICE"],axis=1)
y=car["CAR_PRICE"]

#To get better accuracy i wannna standardize the data
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
for i in a.columns:
    a[i]=scale.fit_transform(a[[i]])
    
a
# Out:
#      symboling  normalized-losses     model  fuel-type  aspiration  \
# 0     1.743470           1.170456 -1.948256   0.328798   -0.469295
# 1     1.743470           1.170456 -1.948256   0.328798   -0.469295
# 2     0.133509           1.170456 -1.948256   0.328798   -0.469295
# 3     0.938490           1.170456 -1.788499   0.328798   -0.469295
# 4     0.938490           1.170456 -1.788499   0.328798   -0.469295
# ..         ...                ...       ...        ...         ...
# 200  -1.476452          -0.940057  1.406641   0.328798   -0.469295
# 201  -1.476452          -0.940057  1.406641   0.328798    2.130854
# 202  -1.476452          -0.940057  1.406641   0.328798   -0.469295
# 203  -1.476452          -0.940057  1.406641  -3.041381    2.130854
# 204  -1.476452          -0.940057  1.406641   0.328798    2.130854
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  ...  \
# 0       -1.141653   -3.050975      1.213330        -0.121867   -1.474700  ...
# ...

# %%
#i saw one error at that time of fitting to resolve that i used two digit data.
#error is float64 is heavy cant process with that data
x=round(a,2)
#splitting the data into training[70%] and testing[30%] 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)

# %%
from sklearn.linear_model import LinearRegression
#INITIALIZING THE ALGORITHM BEFORE FITTING
lr=LinearRegression()
#fit the data to train the model
model=lr.fit(x_train,y_train)
#predict the patterns which are known and which are unknown
y_predict=model.predict(x_test)
#taking the score[accuracy] of our trained model
from sklearn.metrics import r2_score
round((r2_score(y_test,y_predict))*100,2)
# Out:
# 88.25

# %%
#plotting the values with actual and predicted
fig = plt.figure(figsize = (10,8))
plt.scatter(y_test,y_predict, edgecolor = 'black')
fig.suptitle('y_test vs y_pred', fontsize=20)               
plt.xlabel('y_test', fontsize=18)                          
plt.ylabel('y_pred', fontsize=18)
# Out:
# Text(0, 0.5, 'y_pred')

# %%
#taking index of the y_predicted and put it on x_axis 
c = [i for i in range(1,63,1)]
#comparing the actual and predicted values 
fig = plt.figure(figsize=(10,8))
plt.plot(c,y_test, color='black', linewidth=3, linestyle="--")
plt.plot(c,y_predict, color='red',  linewidth=3, linestyle="--")
fig.suptitle('Comparing Actual and Predicted', fontsize=20)  
plt.xlabel('Index', fontsize=18)                            
plt.ylabel('Views', fontsize=18)
# Out:
# Text(0, 0.5, 'Views')

# %%
#representing the errors in the predicted data set with DISTRIBUTION PLOT
fig = plt.figure(figsize=(10,8))
sns.distplot((y_test - y_predict), bins = 20, color = 'maroon')
fig.suptitle('Error Terms', fontsize = 20)                   
plt.xlabel('Errors', fontsize = 18)
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# CONCLUSION:

# %% [markdown]
#     If we absorb above we can see that curb-weight has high cor-relation
#     with many of attributes. if we change the curb-weight many values will change
#     and price also will affect.
