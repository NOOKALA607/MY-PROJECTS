# %%
import pandas as pd

df=pd.read_csv("E:\\STIP TASKS\\train.csv")
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
col_rename=df.rename(columns={"region":"region_no"})

# %%
#ID COLUMN WILL NOT USEFUL
x=col_rename.drop(["employee_id"],axis=1)
x
# Out:
#               department  region_no         education gender  \
# 0      Sales & Marketing   region_7  Master's & above      f
# 1             Operations  region_22        Bachelor's      m
# 2      Sales & Marketing  region_19        Bachelor's      m
# 3      Sales & Marketing  region_23        Bachelor's      m
# 4             Technology  region_26        Bachelor's      m
# ...                  ...        ...               ...    ...
# 54803         Technology  region_14        Bachelor's      m
# 54804         Operations  region_27  Master's & above      f
# 54805          Analytics   region_1        Bachelor's      m
# 54806  Sales & Marketing   region_9               NaN      m
# 54807                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   35                   5.0
# 1                   other                1   30                   5.0
# ...

# %%
null_check=x.isnull()
null_check.sum()
# Out:
# department                 0
# region_no                  0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
import numpy as np
rep_nan=x.replace(" ",np.NaN)
rep_nan
# Out:
#               department  region_no         education gender  \
# 0      Sales & Marketing   region_7  Master's & above      f
# 1             Operations  region_22        Bachelor's      m
# 2      Sales & Marketing  region_19        Bachelor's      m
# 3      Sales & Marketing  region_23        Bachelor's      m
# 4             Technology  region_26        Bachelor's      m
# ...                  ...        ...               ...    ...
# 54803         Technology  region_14        Bachelor's      m
# 54804         Operations  region_27  Master's & above      f
# 54805          Analytics   region_1        Bachelor's      m
# 54806  Sales & Marketing   region_9               NaN      m
# 54807                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   35                   5.0
# 1                   other                1   30                   5.0
# ...

# %%
null_check=rep_nan.isnull()
null_check.sum()
# Out:
# department                 0
# region_no                  0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
data1=rep_nan.fillna(method="bfill")
data1
# Out:
#               department  region_no         education gender  \
# 0      Sales & Marketing   region_7  Master's & above      f
# 1             Operations  region_22        Bachelor's      m
# 2      Sales & Marketing  region_19        Bachelor's      m
# 3      Sales & Marketing  region_23        Bachelor's      m
# 4             Technology  region_26        Bachelor's      m
# ...                  ...        ...               ...    ...
# 54803         Technology  region_14        Bachelor's      m
# 54804         Operations  region_27  Master's & above      f
# 54805          Analytics   region_1        Bachelor's      m
# 54806  Sales & Marketing   region_9        Bachelor's      m
# 54807                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   35                   5.0
# 1                   other                1   30                   5.0
# ...

# %%
#in which department bachelors are high
import matplotlib.pyplot as plt
import seaborn as sns
sns.catplot(x="department",col="education",data=data1,kind="count",aspect=2)
plt.plot()
# Out:
# []

# %%
#for which department got only one time training
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(50,500))
sns.catplot(x="department",col="no_of_trainings",data=data1,kind="count")
plt.plot()
# Out:
# []

# %%
#which education_qualification got promoted
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(50,500))
sns.catplot(x="is_promoted",col="education",data=data1,kind="count")
plt.plot()
# Out:
# []

# %%
#one time trained people got promoted highly?
import matplotlib.pyplot as plt
import seaborn as sns
#plt.figure(figsize=(50,50))
sns.catplot(x="is_promoted",col="no_of_trainings",data=data1,kind="count",aspect=1)
plt.plot()
# Out:
# []

# %% [markdown]
# #statement:
# #1)Bachelors are high in sales
# #2)sales department got one training highly
# #3)one time trained people are not promoted highly
# #4)Bachelors are not promoted highly
#
# #which education persons perform worstly??
# #BACHELORS

# %%
null_check=data1.isnull()
null_check.sum()
# Out:
# department              0
# region_no               0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# is_promoted             0
# dtype: int64

# %%
"""
import string
for i in string.punctuation:
    punct_check=data.astype(str)==str(i)
    print(i,punct_check.sum())
    
"""
# Out:
# '\nimport string\nfor i in string.punctuation:\n    punct_check=data.astype(str)==str(i)\n    print(i,punct_check.sum())\n    \n'

# %%
data1.columns
# Out:
# Index(['department', 'region_no', 'education', 'gender', 'recruitment_channel',
#        'no_of_trainings', 'age', 'previous_year_rating', 'length_of_service',
#        'KPIs_met >80%', 'awards_won?', 'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data1['department']=le.fit_transform(data1['department'])
data1['region_no']=le.fit_transform(data1['region_no'])
data1['education']=le.fit_transform(data1['education'])
data1['gender']=le.fit_transform(data1['gender'])
data1['recruitment_channel']=le.fit_transform(data1['recruitment_channel'])

data1
# Out:
#        department  region_no  education  gender  recruitment_channel  \
# 0               7         31          2       0                    2
# 1               4         14          0       1                    0
# 2               7         10          0       1                    2
# 3               7         15          0       1                    0
# 4               8         18          0       1                    0
# ...           ...        ...        ...     ...                  ...
# 54803           8          5          0       1                    2
# 54804           4         19          2       0                    0
# 54805           0          0          0       1                    0
# 54806           7         33          0       1                    2
# 54807           2         14          0       1                    0
#
#        no_of_trainings  age  previous_year_rating  length_of_service  \
# ...

# %%
data=data1.iloc[:,0:12]
target=data1.iloc[:,12]
data
# Out:
#        department  region_no  education  gender  recruitment_channel  \
# 0               7         31          2       0                    2
# 1               4         14          0       1                    0
# 2               7         10          0       1                    2
# 3               7         15          0       1                    0
# 4               8         18          0       1                    0
# ...           ...        ...        ...     ...                  ...
# 54803           8          5          0       1                    2
# 54804           4         19          2       0                    0
# 54805           0          0          0       1                    0
# 54806           7         33          0       1                    2
# 54807           2         14          0       1                    0
#
#        no_of_trainings  age  previous_year_rating  length_of_service  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data,target,train_size=0.7)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import KFold,cross_val_score

# %%
all_alg=[]
lr=LogisticRegression()
dt=DecisionTreeClassifier()
rf=RandomForestClassifier()
svc=SVC()
knn=KNeighborsClassifier()
all_alg.append(("LogisticRegression:",lr))
all_alg.append(("DecisionTreeClassifier:",dt))
all_alg.append(("RandomForestClassifier:",rf))
all_alg.append(("SVC:",svc))
all_alg.append(("KNN:",knn))
all_alg
# Out:
# [('LogisticRegression:',
#   LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                      intercept_scaling=1, l1_ratio=None, max_iter=100,
#                      multi_class='auto', n_jobs=None, penalty='l2',
#                      random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                      warm_start=False)),
#  ('DecisionTreeClassifier:',
#   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                          max_depth=None, max_features=None, max_leaf_nodes=None,
#                          min_impurity_decrease=0.0, min_impurity_split=None,
#                          min_samples_leaf=1, min_samples_split=2,
#                          min_weight_fraction_leaf=0.0, presort='deprecated',
#                          random_state=None, splitter='best')),
#  ('RandomForestClassifier:',
#   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
for name,model in all_alg:
    kf=KFold(n_splits=10)
    cv_res=cross_val_score(model,x_train,y_train,scoring="accuracy",cv=kf)
    
    print(name,cv_res.mean())
# Out:
# LogisticRegression: 0.915026790351234
# DecisionTreeClassifier: 0.8946696495323103
# RandomForestClassifier: 0.9329599112206134
# SVC: 0.914635887113102
# KNN: 0.9239672683761073

# %% [markdown]
# # before feature_selection

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
import warnings
warnings.filterwarnings("ignore")
lr=RandomForestClassifier(n_estimators=20)


lr.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=20,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
x_train_pred=lr.predict(x_train)
x_test_pred=lr.predict(x_test)

training_score=accuracy_score(x_train_pred,y_train)
testing_score=accuracy_score(x_test_pred,y_test)
print("training-accuracy:",training_score*100)
print("testing-accuracy:",testing_score*100)
# Out:
# training-accuracy: 99.61423172162127
# testing-accuracy: 92.98181597032172

# %% [markdown]
# # after feature selection

# %%
from sklearn.feature_selection import RFE
rfe=RFE(RandomForestClassifier(n_estimators=20),n_features_to_select=1)
rfe.fit(x_train,y_train)
print("support:",rfe.support_)
print("ranking:",rfe.ranking_)
print("estimators:",rfe.estimator_)
for i in zip(data1.columns,rfe.ranking_):
    print(i)
# Out:
# support: [False False False False False False False False False False False  True]
# ranking: [ 5  4 12 11  8 10  2  6  3  7  9  1]
# estimators: RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=20,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# ('department', 5)
# ('region_no', 4)
# ('education', 12)
# ('gender', 11)
# ('recruitment_channel', 8)
# ('no_of_trainings', 10)
# ('age', 2)
# ('previous_year_rating', 6)
# ('length_of_service', 3)
# ('KPIs_met >80%', 7)
# ('awards_won?', 9)
# ('avg_training_score', 1)

# %%
#"Statement:"-According to my feature selection analysis 
#that is better to remove 
#"Education"

# %%
f_data=data1.drop('education',axis=1)
data=f_data.iloc[:,0:11]

target=data1.iloc[:,12]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data,target,train_size=0.7)

# %%
import warnings
warnings.filterwarnings("ignore")
lr=RandomForestClassifier(n_estimators=20)
lr.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=20,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
x_train_pred=lr.predict(x_train)
x_test_pred=lr.predict(x_test)

training_score=accuracy_score(x_train_pred,y_train)
testing_score=accuracy_score(x_test_pred,y_test)
print("training-accuracy:",training_score*100)
print("testing-accuracy:",testing_score*100)
# Out:
# training-accuracy: 99.58816629740649
# testing-accuracy: 93.37712096332787

# %%
#as we absorb from above training-accuracy, and testing-score
#its overfitting: if the error-rate is low in training-set 
                    #and error-rate is high in testing-set:

# %%
c=[i for i in range(len(y_test))]
plt.scatter(c,y_test,label="Actual_values",color="red")
plt.legend(loc="center")
plt.show()

# %%
#scatter-plot for accuracy or error-rate
c=[i for i in range(len(y_test))]
plt.scatter(c,y_test,label="Actual_values",color="red")
plt.scatter(c,y_pred_train,label="Predicted_values",color="blue")
plt.legend(loc="center")
plt.plot()
# Out:
# []

# %%
#line-plot for accuracy or error-rate
c=[i for i in range(len(y_test))]
plt.plot(c,y_test,label="Actual_values",color="red")
plt.plot(c,y_pred_train,label="Predicted_values",color="blue")
plt.legend(loc="center")
plt.plot()
# Out:
# []

# %%
from sklearn.metrics import *
print("confusion_matrix:\n",confusion_matrix(y_test,y_pred_train))
print("classification_report:\n",classification_report(y_test,y_pred_train))
# Out:
# confusion_matrix:
#  [[13887  1163]
#  [ 1290   103]]
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92     15050
#            1       0.08      0.07      0.08      1393
#
#     accuracy                           0.85     16443
#    macro avg       0.50      0.50      0.50     16443
# weighted avg       0.84      0.85      0.85     16443

# %%
import pandas as pd
import copy
test_df=pd.read_csv("E:\\STIP TASKS\\test.csv")
col_rename=test_df.rename(columns={"region":"region_no"})
#ID COLUMN WILL NOT USEFUL
x=col_rename.drop(["employee_id"],axis=1)
import numpy as np
rep_nan=x.replace(" ",np.NaN)
data1=rep_nan.fillna(method="bfill")
data=copy.deepcopy(data1)
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data1['department']=le.fit_transform(data1['department'])
data1['region_no']=le.fit_transform(data1['region_no'])
data1['education']=le.fit_transform(data1['education'])
data1['gender']=le.fit_transform(data1['gender'])
data1['recruitment_channel']=le.fit_transform(data1['recruitment_channel'])
data=data1.drop("education",axis=1)

# %%
y_pred=lr.predict(data)

# %%
data["pred_is_promoted"]=y_pred
data
# Out:
#        department  region_no  gender  recruitment_channel  no_of_trainings  \
# 0               8         18       1                    2                1
# 1               2         28       0                    0                1
# 2               7          4       1                    0                1
# 3               5         11       0                    0                3
# 4               1         21       1                    2                1
# ...           ...        ...     ...                  ...              ...
# 23485           3         11       1                    2                1
# 23486           8         17       1                    2                1
# 23487           2          7       0                    2                1
# 23488           5         24       1                    2                3
# 23489           8          8       1                    0                3
#
# ...

# %%
#test_df.to_csv("HR_ANALYTICS_PRED_DATA.csv")
